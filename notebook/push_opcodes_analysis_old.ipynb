# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [12, 8]

# %%
INPUT_FILE = '../data/5_histogram.csv'

# %%
def read_file(fpath):
    fobj = open(fpath, 'r')
    data = fobj.read()
    fobj.close()
    return [line.split(',') for line in data.split('\n')]

# %%
data = read_file(INPUT_FILE)[:-1]

# %%
columns = data[0]

# %%
df = pd.DataFrame(data[2:], columns=columns)

# %%
df
# Out:
#         Block#  Gas used STOP    ADD   MUL   SUB   DIV SDIV  MOD SMOD  ...  -  \
# 0     12205970  12279594  138  11089  1873  3848  1442    0    3    0  ...  0
# 1     12205971  12469595  154  13521  1924  4420  2062    0    9    0  ...  0
# 2     12205972  12470726  180  12765  1969  4666  1628    2   14    0  ...  0
# 3     12205973  12472873  162  11487  1657  4185  1383    0    5    0  ...  0
# 4     12205974  12476769  162   8516  1255  3375  1245    0    4    0  ...  0
# ...        ...       ...  ...    ...   ...   ...   ...  ...  ...  ...  ... ..
# 5885  12211762  12384642  158  12826  1733  4088  1634    0   27    0  ...  0
# 5886  12211764  12420064  136  14433  2049  5026  2023    0  136    0  ...  0
# 5887  12211763  12400640   89   8892  1334  3310  1329    0   22    0  ...  0
# 5888  12211765  12419291  141  12804  2038  4580  1898    2   75    0  ...  0
# 5889  12211766  12449977  160   9885  1392  3677  1999    0   34    0  ...  0
#
# ...

# %%
df['PUSH0'] = df['PUSH0'].astype(int)
df['PUSH1'] = df['PUSH1'].astype(int)
df['PUSH2'] = df['PUSH2'].astype(int)
df['PUSH3'] = df['PUSH3'].astype(int)
df['PUSH4'] = df['PUSH4'].astype(int)
df['PUSH5'] = df['PUSH5'].astype(int)
df['PUSH6'] = df['PUSH6'].astype(int)
df['PUSH7'] = df['PUSH7'].astype(int)
df['PUSH8'] = df['PUSH8'].astype(int)
df['PUSH9'] = df['PUSH9'].astype(int)
df['PUSH10'] = df['PUSH10'].astype(int)
df['PUSH11'] = df['PUSH11'].astype(int)
df['PUSH12'] = df['PUSH12'].astype(int)
df['PUSH13'] = df['PUSH13'].astype(int)
df['PUSH14'] = df['PUSH14'].astype(int)
df['PUSH15'] = df['PUSH15'].astype(int)
df['PUSH16'] = df['PUSH16'].astype(int)
df['PUSH17'] = df['PUSH17'].astype(int)
df['PUSH18'] = df['PUSH18'].astype(int)
df['PUSH19'] = df['PUSH19'].astype(int)
df['PUSH20'] = df['PUSH20'].astype(int)
df['PUSH21'] = df['PUSH21'].astype(int)
df['PUSH22'] = df['PUSH22'].astype(int)
df['PUSH23'] = df['PUSH23'].astype(int)
df['PUSH24'] = df['PUSH24'].astype(int)
df['PUSH25'] = df['PUSH25'].astype(int)
df['PUSH26'] = df['PUSH26'].astype(int)
df['PUSH27'] = df['PUSH27'].astype(int)
df['PUSH28'] = df['PUSH28'].astype(int)
df['PUSH29'] = df['PUSH29'].astype(int)
df['PUSH30'] = df['PUSH30'].astype(int)
df['PUSH31'] = df['PUSH31'].astype(int)
df['PUSH32'] = df['PUSH32'].astype(int)

df['CALLDATASIZE'] = df['CALLDATASIZE'].astype(int)
df['RETURNDATASIZE'] = df['RETURNDATASIZE'].astype(int)
df['MSIZE'] = df['RETURNDATASIZE'].astype(int)

# %%
df['ALLPUSH'] = df['PUSH1'] + df['PUSH2'] +  df['PUSH3'] + df['PUSH4']  \
    + df['PUSH5'] + df['PUSH6'] + df['PUSH7'] + df['PUSH8'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2'] \
    + df['PUSH1'] + df['PUSH2'] + df['PUSH1'] + df['PUSH2']

# %%
df['PUSH0_perc'] = (df['PUSH0'] / df['ALLPUSH'] ) * 100
df['PUSH0_perc_vs_PUSH1'] = (df['PUSH0'] / df['PUSH1'] ) * 100

# %%
df = df[df.PUSH1 != 0]

# %%
df
# Out:
#         Block#  Gas used STOP    ADD   MUL   SUB   DIV SDIV  MOD SMOD  ...  -  \
# 0     12205970  12279594  138  11089  1873  3848  1442    0    3    0  ...  0
# 1     12205971  12469595  154  13521  1924  4420  2062    0    9    0  ...  0
# 2     12205972  12470726  180  12765  1969  4666  1628    2   14    0  ...  0
# 3     12205973  12472873  162  11487  1657  4185  1383    0    5    0  ...  0
# 4     12205974  12476769  162   8516  1255  3375  1245    0    4    0  ...  0
# ...        ...       ...  ...    ...   ...   ...   ...  ...  ...  ...  ... ..
# 5885  12211762  12384642  158  12826  1733  4088  1634    0   27    0  ...  0
# 5886  12211764  12420064  136  14433  2049  5026  2023    0  136    0  ...  0
# 5887  12211763  12400640   89   8892  1334  3310  1329    0   22    0  ...  0
# 5888  12211765  12419291  141  12804  2038  4580  1898    2   75    0  ...  0
# 5889  12211766  12449977  160   9885  1392  3677  1999    0   34    0  ...  0
#
# ...

# %%
df = df.sort_values(by=['PUSH0_perc'])
df = df[df.PUSH0_perc > 1]
df[
    ['Block#', 
     'PUSH1', 'PUSH2', 'PUSH3', 'PUSH4', 'PUSH5', 'PUSH6', 'PUSH7', 'PUSH8', 
     'PUSH9', 'PUSH10', 'PUSH11', 'PUSH12', 'PUSH13', 'PUSH14', 'PUSH15', 'PUSH16', 
     'PUSH17', 'PUSH18', 'PUSH19', 'PUSH20', 'PUSH21', 'PUSH22', 'PUSH23', 'PUSH24', 
     'PUSH25', 'PUSH26', 'PUSH27', 'PUSH28', 'PUSH29', 'PUSH30', 'PUSH31', 'PUSH32',
     'ALLPUSH', 'PUSH0', 'PUSH0_perc']]
# Out:
#         Block#  PUSH1  PUSH2  PUSH3  PUSH4  PUSH5  PUSH6  PUSH7  PUSH8  PUSH9  \
# 4056  12209969  42286  31102    266   7628    163      9      3    468      8
# 4202  12210111  37387  27192    131   7460    178     25      0    133      9
# 531   12206496  55098  36971    201   8188    133      1     16     98      1
# 5606  12211489  29925  23043     44   6501    158      7      4     62      1
# 1990  12207932  37820  27714     88   5618    163      3     11    190      6
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2643  12208569   2088     75      0      6      0      0      0      0      0
# 1342  12207295   2088     75      0      6      0      0      0      0      0
# 5418  12211306   2088     75      0      6      0      0      0      0      0
# 4054  12209968   2102     79      0      6      0      0      0      0      0
# 2833  12208755   2102     79      0      6      0      0      0      0      0
#
# ...

# %%
df['PUSH0_perc'].mean()
# Out:
# 1.0542493540409525

# %%
df['PUSH0_perc'].min()
# Out:
# 0.6125282036123074

# %%
df['PUSH0_perc'].max()
# Out:
# 2.531824112274763

# %%
df['PUSH0'].mean()
# Out:
# 8287.38766066838

# %%
fig, ax = plt.subplots()
push0_h, push0_bins = np.histogram(df['PUSH0'])
push1_h, push1_bins = np.histogram(df['PUSH1'])
push2_h, push2_bins = np.histogram(df['PUSH2'])

width = (push0_bins[1] - push1_bins[0]) / 3

ax.bar(push0_bins[:-1], push0_h, width=width)
ax.bar(push1_bins[:-1]+width, push1_h, width=width)
ax.bar(push2_bins[:-1]+width, push2_h, width=width)
# Out:
# <BarContainer object of 10 artists>

# %%
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=20)
plt.hist(df['PUSH0'], **kwargs)
plt.hist(df['PUSH1'], **kwargs)
plt.hist(df['PUSH2'], **kwargs)
plt.hist(df['PUSH3'], **kwargs)
plt.hist(df['PUSH4'], **kwargs)
plt.hist(df['PUSH5'], **kwargs)
plt.hist(df['PUSH6'], **kwargs)
plt.hist(df['PUSH7'], **kwargs)
plt.hist(df['PUSH8'], **kwargs)
plt.hist(df['PUSH9'], **kwargs)
plt.hist(df['PUSH10'], **kwargs)
plt.hist(df['PUSH11'], **kwargs)
plt.hist(df['PUSH12'], **kwargs)
plt.hist(df['PUSH13'], **kwargs)
plt.hist(df['PUSH14'], **kwargs)
plt.hist(df['PUSH15'], **kwargs)
plt.hist(df['PUSH16'], **kwargs)
plt.hist(df['PUSH17'], **kwargs)
plt.hist(df['PUSH18'], **kwargs)
plt.hist(df['PUSH19'], **kwargs)
plt.hist(df['PUSH20'], **kwargs)
plt.hist(df['PUSH21'], **kwargs)
plt.hist(df['PUSH22'], **kwargs)
plt.hist(df['PUSH23'], **kwargs)
plt.hist(df['PUSH24'], **kwargs)
plt.hist(df['PUSH25'], **kwargs)
plt.hist(df['PUSH26'], **kwargs)
plt.hist(df['PUSH27'], **kwargs)
plt.hist(df['PUSH28'], **kwargs)
plt.hist(df['PUSH29'], **kwargs)
plt.hist(df['PUSH30'], **kwargs)
plt.hist(df['PUSH31'], **kwargs)
plt.hist(df['PUSH32'], **kwargs)
# Out:
# (array([9.340e+02, 4.423e+03, 4.310e+02, 1.300e+01, 1.000e+00, 2.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+01, 9.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([2.000000e+00, 9.374500e+02, 1.872900e+03, 2.808350e+03,
#         3.743800e+03, 4.679250e+03, 5.614700e+03, 6.550150e+03,
#         7.485600e+03, 8.421050e+03, 9.356500e+03, 1.029195e+04,
#         1.122740e+04, 1.216285e+04, 1.309830e+04, 1.403375e+04,
#         1.496920e+04, 1.590465e+04, 1.684010e+04, 1.777555e+04,
#         1.871100e+04]),
#  [<matplotlib.patches.Polygon at 0x7efd90685cd0>])

# %%
#df2 = df.copy()
fig, ax = plt.subplots()
df.hist(column=['PUSH0'], ax=ax, label=('PUSH0', '?'))
df.hist(column=['PUSH1'], ax=ax)
df.hist(column=['PUSH2'], ax=ax)
df.hist(column=['PUSH3'], ax=ax)
df.hist(column=['PUSH4'], ax=ax)
df.hist(column=['PUSH5'], ax=ax)
df.hist(column=['PUSH6'], ax=ax)
df.hist(column=['PUSH7'], ax=ax)
df.hist(column=['PUSH8'], ax=ax)
df.hist(column=['PUSH9'], ax=ax)
df.hist(column=['PUSH10'], ax=ax)
df.hist(column=['PUSH11'], ax=ax)
df.hist(column=['PUSH12'], ax=ax)
df.hist(column=['PUSH13'], ax=ax)
df.hist(column=['PUSH14'], ax=ax)
df.hist(column=['PUSH15'], ax=ax)
df.hist(column=['PUSH16'], ax=ax)
df.hist(column=['PUSH17'], ax=ax)
df.hist(column=['PUSH18'], ax=ax)
df.hist(column=['PUSH19'], ax=ax)
df.hist(column=['PUSH20'], ax=ax)
df.hist(column=['PUSH21'], ax=ax)
df.hist(column=['PUSH22'], ax=ax)
df.hist(column=['PUSH23'], ax=ax)
df.hist(column=['PUSH24'], ax=ax)
df.hist(column=['PUSH25'], ax=ax)
df.hist(column=['PUSH26'], ax=ax)
df.hist(column=['PUSH27'], ax=ax)
df.hist(column=['PUSH28'], ax=ax)
df.hist(column=['PUSH29'], ax=ax)
df.hist(column=['PUSH30'], ax=ax)
df.hist(column=['PUSH31'], ax=ax)
df.hist(column=['PUSH32'], ax=ax)
# Out:
# array([<AxesSubplot:title={'center':'PUSH32'}>], dtype=object)

# %%
df2 = df[['PUSH0', 'PUSH1', 'PUSH2', 'PUSH3', 'PUSH4', 'PUSH5']]
plt.figure()
df2.plot.hist(stacked=True, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist('PUSH0')
# Out:
# array([[<AxesSubplot:title={'center':'PUSH0'}>]], dtype=object)

# %%
df[['PUSH1', 'PUSH2', 'PUSH3', 'PUSH4', 'PUSH5', 'PUSH6', 'PUSH7', 'PUSH8', 'PUSH9', 
    'PUSH10', 'PUSH11', 'PUSH12', 'PUSH13', 'PUSH14', 'PUSH15', 'PUSH16', 'PUSH17', 'PUSH18', 'PUSH19',
    'PUSH20', 'PUSH21', 'PUSH22', 'PUSH23', 'PUSH24', 'PUSH25', 'PUSH26', 'PUSH27', 'PUSH28', 'PUSH29',
    'PUSH30', 'PUSH31', 'PUSH32']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['PUSH1', 'PUSH2', 'PUSH3', 'PUSH4', 'PUSH5', 'PUSH6', 'PUSH7', 'PUSH8', 'PUSH9', 
    'PUSH10', 'PUSH11', 'PUSH12', 'PUSH13', 'PUSH14', 'PUSH15', 'PUSH16', 'PUSH17', 'PUSH18', 'PUSH19',
    'PUSH20', 'PUSH21', 'PUSH22', 'PUSH23', 'PUSH24', 'PUSH25', 'PUSH26', 'PUSH27', 'PUSH28', 'PUSH29',
    'PUSH30', 'PUSH31', 'PUSH32', 'MSIZE', 'CALLDATASIZE', 'RETURNDATASIZE']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2 = df.copy()
df2['PUSH1'] = df2['PUSH1'] - df2['PUSH0']
df2[['PUSH0', 'PUSH1', 'PUSH2', 'PUSH3', 'PUSH4', 'PUSH5', 'PUSH6', 'PUSH7', 'PUSH8', 'PUSH9', 
    'PUSH10', 'PUSH11', 'PUSH12', 'PUSH13', 'PUSH14', 'PUSH15', 'PUSH16', 'PUSH17', 'PUSH18', 'PUSH19',
    'PUSH20', 'PUSH21', 'PUSH22', 'PUSH23', 'PUSH24', 'PUSH25', 'PUSH26', 'PUSH27', 'PUSH28', 'PUSH29',
    'PUSH30', 'PUSH31', 'PUSH32', 'MSIZE', 'CALLDATASIZE', 'RETURNDATASIZE']].sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.hist('PUSH1')
# Out:
# array([[<AxesSubplot:title={'center':'PUSH1'}>]], dtype=object)

# %%
df.hist('PUSH2')
# Out:
# array([[<AxesSubplot:title={'center':'PUSH2'}>]], dtype=object)
